# %%
import numpy as np
import time

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
import numpy as np
import time

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
            # Check for convergence
            if np.linalg.norm(x_new - x, ord=np.inf) < tol:
                return x_new, k
        x = x_new
    return x, max_iterations

# %%
#Jacobi
start_time = time.perf_counter()


#Coding Challenge 7a:
#A = np.array([
#	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
# [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
# [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
# [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
# [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
#b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)

    #Result: Diverges
    #Iterations: 100
    #Elapsed time: 0.017278505489230156

#Coding Challenge 7b:
#A = np.array([[1, 	1], [1, 1.0001]])
#b = np.array([1, 1.0001])

    #Result: Diverges
    #Iterations: 100
    #Elapsed time: 0.008014915511012077

#Coding Challenge 7c:
A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])

    #Result: Diverges
    #Iterations: 100
    #Elapsed time: 0.004819687455892563

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")

end_time = time.perf_counter()
print("Elapsed time:", end_time-start_time)
# Out:
# Solution: [0.         0.00498727]
# Iterations: 100
# Elapsed time: 0.004389755427837372

# %%
#Gauss-Seidel
start_time = time.perf_counter()


#Coding Challenge 7a:
A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)

    #Result: Converges
    #Iterations: 20
    #Elapsed time: 0.004120523110032082

#Coding Challenge 7b:
#A = np.array([[1, 	1], [1, 1.0001]])
#b = np.array([1, 1.0001])

    #Result: Diverges
    #Iterations: 100
    #Elapsed time: 0.01142888329923153

#Coding Challenge 7c:
#A = np.array([[1, 	1], [1, 1.0001]])
#b = np.array([1, 1.0001])

    #Result: Diverges
    #Iterations: 100
    #Elapsed time: 0.010551271960139275

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")

end_time = time.perf_counter()
print("Elapsed time:", end_time-start_time)
# Out:
# Solution: [0.99999926 1.00000095 0.99999975 0.99999995 1.00000009]
# Iterations: 20
# Elapsed time: 0.0043897563591599464
