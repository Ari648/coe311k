# %%
import numpy as np
import matplotlib.pyplot as plt
# Define the parameters
k = 1.0        # Constant in the equation (e.g., spring constant)
h_values = [0.01, 0.02, 0.03, 0.05, 0.1, 0.2, 0.3, 0.5]       # Step size
x_start = 0    # Start of the interval
x_end = 10     # End of the interval
y_0 = 1.0      # Initial condition for y
v_0 = 0.0      # Initial condition for dy/dx

def eulerSteps(k, h, x_start, x_end, y_0, v_0):
    # Create arrays to store x, y, and v values
    x_values = np.arange(x_start, x_end + h, h)
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))
    # Set initial conditions
    y_values[0] = y_0
    v_values[0] = v_0
    
    # Euler's Method loop
    for i in range(1, len(x_values)):
        # Current values
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]    
        # Update equations
        y_values[i] = y_n + h * v_n
        v_values[i] = v_n + h * (-k * y_n)
    return x_values, y_values

# Plot the results
plt.figure(figsize=(10, 5))

for h in h_values:
    x, y = eulerSteps(k, h, x_start, x_end, y_0, v_0)
    plt.plot(x, y, label=f'Euler\'s Method (h={h})')


plt.xlabel('x')
plt.ylabel('y and v')
plt.title('Solution of d²y/dx² = -ky using Euler\'s Method')
plt.legend()
plt.grid(True)
plt.show()

# %%
#In-Class Challenge 16

#Euler's Method seems to become more unsable the larger x gets, start around x = 2
#When h is greater than 0.1 it becomes especially unstable the larger x gets

#When changing the value of k, I noticed that the function would get more and more unsaable the larger the value got.
#The position and velocity functions had a proportional amount of oscillations depending on k.

#When setting constant (k = 10) and step size (h = 0.01), I see that as x increases Euler's Method becomes more and more unstable. 
#If we were to increase the step size (h), the function would become even more unstable because k and h sould be inversly proportional to keep it stable.
