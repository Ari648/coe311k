# %%
import numpy as np
import time

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
# Example usage
start_time = time.perf_counter()


#Code Challenge A:
#A = np.array([
#	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
# [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
# [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
# [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
# [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)

#b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)


A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])


x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")

end_time = time.perf_counter()
print("Elapsed time:", end_time-start_time)
# Out:
# Solution: [0.         0.00498727]
# Iterations: 100
# Elapsed time: 0.007279559969902039

# %%
import numpy as np
import time

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
            # Check for convergence
            if np.linalg.norm(x_new - x, ord=np.inf) < tol:
                return x_new, k
        x = x_new
    return x, max_iterations

# %%
# Example usage
start_time = time.perf_counter()

#Code Challenge A:
#A = np.array([
#	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
# [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
# [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
# [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
# [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)

#b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)


A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])


x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")

end_time = time.perf_counter()
print("Elapsed time:", end_time-start_time)
# Out:
# Solution: [0.99014933 0.00994967]
# Iterations: 100
# Elapsed time: 0.016005825251340866

# %%
import numpy as np
A = np.array([[2,1],[1,1]])
B = np.array([[2,4],[1,2]])
print(np.linalg.det(A))
print(np.linalg.det(B))
# Out:
# 1.0
# 0.0

# %%
print("A:")
print(f"A:{A}")
kappa = np.linalg.cond(A, 2)
print(kappa)
# Out:
# A:
# A:[[1.     1.    ]
#  [1.     1.0001]]
# 40002.00007491187

# %%
A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)

# %%
#def diagonaldominance():


diagonal = A[4, 4]

j = 0
for j in range len(A):
    otherElements = A(i, j)
    if abs(diagonal) < abs(otherElements):
        return False

print(len(A))

print(diagonal)
print("Is the matrix diagonally dominant?")
# Out:
#   File "<ipython-input-30-1503439f3759>", line 7
#     for j in range len(A):
#                    ^
# SyntaxError: invalid syntax
