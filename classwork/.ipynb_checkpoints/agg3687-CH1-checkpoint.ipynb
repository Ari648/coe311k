# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.subplot(2, 4, 1) # (row, column, active area)
plt.plot(x, -x*x, 'r--')
plt.subplot(2, 4, 6)
plt.plot(x, np.cos(x), 'g-^')
plt.subplot(2, 4, 3)
plt.plot(np.arctan(x), x, 'y-s')
plt.subplot(2, 4, 8)
plt.plot(-x, np.exp(x), 'b-o')
plt.show()
