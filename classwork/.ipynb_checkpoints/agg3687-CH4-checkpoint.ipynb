# %%
import math
import random
import numpy
import matplotlib.pyplot as plt


def leibniz_pi():
    calculated_pi = 0
    for n in range (5000):
        calculated_pi += (((-1)**n)/(2*n+1))*4
        if (((n%100) == 0) and n != 0 ):
            print(abs((numpy.pi - calculated_pi)/numpy.pi))
            #print (calculated_pi)
    return ()
                
leibniz_pi()
# Out:
# 0.00315150580387468
# 3.1514934010709914
# 0.0015836214753932633
# 3.1465677471829556
# 0.001057505009525431
# 3.1449149035588526
# 0.000793789005751022
# 3.144086415298761
# 0.0006353484414075896
# 3.143588659585789
# 0.0005296333874729713
# 3.143256545948974
# 0.00045407949250305123
# 3.1430191863875865
# 0.0003973904646130839
# 3.142841092554028
# 0.00035328500350548475
# 3.1427025311614294
# 0.0003179918149508013
# 3.1425916543395442
# 0.00028910973709111743
# 3.14250091861592
# 0.0002650373280719025
# 3.142425292912591
# 0.00024466551819292626
# 3.1423612929843348
# 0.0002272018883944259
# 3.1423064293732548
# 0.00021206519044809295
# 3.142258876034187
# 0.00019881939733771412
# 3.1422172631478604
# 0.00018713101627287207
# 3.1421805430157748
# 0.000176740622792398
# 3.1421479006319486
# 0.0001674433793591898
# 3.14211869248028
# 0.00015907539545632673
# 3.1420924036835256
# 0.00015150398293974264
# 3.142068617389586
# 0.00014462056781363417
# 3.1420469925031944
# ...
