# %% [markdown]
# # COE311K Final Project Part 1
# ## Members: Ari George

# %%
#Part 1: Model Selection
#I am choosing option A, a spring-mass system (mechanical oscillations)

# %%
#Part 2: Parameter Research
# 1. Reasearch realistic parameter values:
# 2. Cite sources
# 3. Justify choices
# 4. Define appropriate initial conditions

# %%
#Part 3. Numerical Implementation

# %%
#Part 4. Stability Analysis
